# %%
import tabula as tb
import PyPDF2 as pypdf2
import pandas as pd
import numpy as np
import glob

# %%
def pdf_to_df(path, group, society, month, from_page=2):

    df_list = []
    all_files = pd.Series(glob.glob(path + "\\*.pdf"))

    pattern = group + '_' + society + month
    files_list = all_files[
        all_files.astype(str).str.contains(pattern)].tolist()
    print(files_list)
    
    for file in files_list:
        
        with open(file, "rb") as pdf_file:
            
            pdf_reader = pypdf2.PdfFileReader(pdf_file)
            to_page = pdf_reader.numPages
        
        if to_page > 2 :

            dfs = tb.read_pdf(
                file,
                pages=np.arange(from_page, to_page+1).tolist(),
                multiple_tables=True,
                stream=True)
        else:
            
            dfs = tb.read_pdf(
                file,
                pages=2,
                multiple_tables=True,
                stream=True)
            
        
        aux_df = pd.concat(dfs)
        df_list.append(aux_df)
        
    df = pd.concat(df_list)
    
    return df
    
    
def anti_join(x, y, on):
    """Return rows in x which are not present in y"""
    ans = pd.merge(left=x, right=y, how='left', indicator=True, on=on)
    ans = ans.loc[ans._merge == 'left_only', :].drop(columns='_merge')
    return ans

# %%
path = "C:/projects/pdf_mining/data"
groups = ['at', 'co', 'hc', 'la', 'li', 'po', 'pu']
societies = ['cli', 'diag', 'lab', 'cem', 'hos', 'ima', 'rad', 'res', 'reg']
months = ['1', '2', '3', '4', '5', '6', '7', '8']

# %%
df_list = []

for group in groups:
    for society in societies:
        for month in months:            
                        
            try:
                
                aux_df = pdf_to_df(path, group, society, month)
    
                # cambiar el el nombre de columnas
                new_header = aux_df.iloc[0]
                aux1_df = aux_df.iloc[1:]
                aux1_df.columns = new_header

                aux2_df = aux1_df[aux1_df['RUT'].notna()].copy()
                aux2_df = aux2_df[aux2_df['RUT']!='RUT'].copy().reset_index(drop=True)
                aux2_df.reset_index(drop=True, inplace=True)

                # Se agregan columnas de grupo y sociedad
                aux2_df['grupo'] = group
                aux2_df['mes'] = month
                aux2_df['sociedad'] = society

                # Se le quita el '.' al 'RUT'
                aux2_df['RUT'] = aux2_df['RUT'].apply(lambda x: x.replace('.',''))
                aux2_df['Remuneración'] = aux2_df['Remuneración'].apply(lambda x: x.replace('.',''))


                df_list.append(aux2_df)
                
                print(group + '_' + society + month)
            
            except:
                
                print('no existe el archivo %s_%s%s' % (group, society, month))


df = pd.concat(df_list)
# Out:
# ['C:/projects/pdf_mining/data\\at_cli1a.pdf']
# at_cli1
# ['C:/projects/pdf_mining/data\\at_cli2a.pdf']
# at_cli2
# ['C:/projects/pdf_mining/data\\at_cli3a.pdf']
# at_cli3
# ['C:/projects/pdf_mining/data\\at_cli4a.pdf']
# at_cli4
# ['C:/projects/pdf_mining/data\\at_cli5a.pdf']
# at_cli5
# ['C:/projects/pdf_mining/data\\at_cli6a.pdf']
# at_cli6
# ['C:/projects/pdf_mining/data\\at_cli7a.pdf']
# at_cli7
# ['C:/projects/pdf_mining/data\\at_cli8a.pdf']
# at_cli8
# ['C:/projects/pdf_mining/data\\at_diag1a.pdf']
# at_diag1
# ['C:/projects/pdf_mining/data\\at_diag2a.pdf']
# at_diag2
# ['C:/projects/pdf_mining/data\\at_diag3a.pdf']
# at_diag3
# ['C:/projects/pdf_mining/data\\at_diag4a.pdf']
# at_diag4
# ['C:/projects/pdf_mining/data\\at_diag5a.pdf']
# at_diag5
# ['C:/projects/pdf_mining/data\\at_diag6a.pdf']
# at_diag6
# ['C:/projects/pdf_mining/data\\at_diag7a.pdf']
# at_diag7
# ['C:/projects/pdf_mining/data\\at_diag8a.pdf']
# at_diag8
# ['C:/projects/pdf_mining/data\\at_lab1a.pdf']
# at_lab1
# ['C:/projects/pdf_mining/data\\at_lab2a.pdf']
# at_lab2
# ['C:/projects/pdf_mining/data\\at_lab3a.pdf']
# at_lab3
# ['C:/projects/pdf_mining/data\\at_lab4a.pdf']
# at_lab4
# ['C:/projects/pdf_mining/data\\at_lab5a.pdf']
# at_lab5
# ['C:/projects/pdf_mining/data\\at_lab6a.pdf']
# at_lab6
# ['C:/projects/pdf_mining/data\\at_lab7.pdf']
# at_lab7
# ['C:/projects/pdf_mining/data\\at_lab8a.pdf']
# at_lab8
# []
# no existe el archivo at_cem1
# []
# no existe el archivo at_cem2
# []
# no existe el archivo at_cem3
# []
# no existe el archivo at_cem4
# []
# no existe el archivo at_cem5
# []
# no existe el archivo at_cem6
# []
# no existe el archivo at_cem7
# []
# no existe el archivo at_cem8
# []
# no existe el archivo at_hos1
# []
# no existe el archivo at_hos2
# []
# no existe el archivo at_hos3
# []
# no existe el archivo at_hos4
# []
# no existe el archivo at_hos5
# []
# no existe el archivo at_hos6
# []
# no existe el archivo at_hos7
# []
# no existe el archivo at_hos8
# []
# no existe el archivo at_ima1
# []
# no existe el archivo at_ima2
# []
# no existe el archivo at_ima3
# []
# no existe el archivo at_ima4
# []
# no existe el archivo at_ima5
# []
# no existe el archivo at_ima6
# []
# no existe el archivo at_ima7
# []
# no existe el archivo at_ima8
# []
# no existe el archivo at_rad1
# []
# no existe el archivo at_rad2
# []
# no existe el archivo at_rad3
# []
# no existe el archivo at_rad4
# []
# no existe el archivo at_rad5
# []
# no existe el archivo at_rad6
# []
# no existe el archivo at_rad7
# []
# no existe el archivo at_rad8
# []
# no existe el archivo at_res1
# []
# no existe el archivo at_res2
# []
# no existe el archivo at_res3
# []
# no existe el archivo at_res4
# []
# no existe el archivo at_res5
# []
# no existe el archivo at_res6
# []
# no existe el archivo at_res7
# []
# no existe el archivo at_res8
# []
# no existe el archivo at_reg1
# []
# no existe el archivo at_reg2
# []
# no existe el archivo at_reg3
# []
# no existe el archivo at_reg4
# []
# no existe el archivo at_reg5
# []
# no existe el archivo at_reg6
# []
# no existe el archivo at_reg7
# []
# no existe el archivo at_reg8
# ['C:/projects/pdf_mining/data\\co_cli1a.pdf']
# co_cli1
# ['C:/projects/pdf_mining/data\\co_cli2a.pdf']
# co_cli2
# ['C:/projects/pdf_mining/data\\co_cli3a.pdf']
# co_cli3
# ['C:/projects/pdf_mining/data\\co_cli4a.pdf']
# co_cli4
# ['C:/projects/pdf_mining/data\\co_cli5a.pdf']
# co_cli5
# ['C:/projects/pdf_mining/data\\co_cli6a.pdf']
# co_cli6
# ['C:/projects/pdf_mining/data\\co_cli7a.pdf']
# co_cli7
# ['C:/projects/pdf_mining/data\\co_cli8a.pdf', 'C:/projects/pdf_mining/data\\co_cli8b.pdf']
# co_cli8
# []
# no existe el archivo co_diag1
# []
# no existe el archivo co_diag2
# []
# no existe el archivo co_diag3
# []
# no existe el archivo co_diag4
# []
# no existe el archivo co_diag5
# []
# no existe el archivo co_diag6
# []
# no existe el archivo co_diag7
# []
# no existe el archivo co_diag8
# []
# no existe el archivo co_lab1
# []
# no existe el archivo co_lab2
# []
# no existe el archivo co_lab3
# []
# no existe el archivo co_lab4
# []
# no existe el archivo co_lab5
# []
# no existe el archivo co_lab6
# []
# no existe el archivo co_lab7
# []
# no existe el archivo co_lab8
# ['C:/projects/pdf_mining/data\\co_cem1a.pdf']
# co_cem1
# ['C:/projects/pdf_mining/data\\co_cem2a.pdf']
# co_cem2
# ['C:/projects/pdf_mining/data\\co_cem3a.pdf']
# co_cem3
# ['C:/projects/pdf_mining/data\\co_cem4a.pdf']
# co_cem4
# ['C:/projects/pdf_mining/data\\co_cem5a.pdf']
# co_cem5
# ['C:/projects/pdf_mining/data\\co_cem6a.pdf']
# co_cem6
# ['C:/projects/pdf_mining/data\\co_cem7a.pdf']
# co_cem7
# ['C:/projects/pdf_mining/data\\co_cem8a.pdf', 'C:/projects/pdf_mining/data\\co_cem8b.pdf']
# co_cem8
# []
# no existe el archivo co_hos1
# []
# no existe el archivo co_hos2
# []
# no existe el archivo co_hos3
# []
# no existe el archivo co_hos4
# []
# no existe el archivo co_hos5
# []
# no existe el archivo co_hos6
# []
# no existe el archivo co_hos7
# []
# no existe el archivo co_hos8
# []
# no existe el archivo co_ima1
# []
# no existe el archivo co_ima2
# []
# no existe el archivo co_ima3
# []
# no existe el archivo co_ima4
# []
# no existe el archivo co_ima5
# []
# no existe el archivo co_ima6
# []
# no existe el archivo co_ima7
# []
# no existe el archivo co_ima8
# []
# no existe el archivo co_rad1
# []
# no existe el archivo co_rad2
# []
# no existe el archivo co_rad3
# []
# no existe el archivo co_rad4
# []
# no existe el archivo co_rad5
# []
# no existe el archivo co_rad6
# []
# no existe el archivo co_rad7
# []
# no existe el archivo co_rad8
# []
# no existe el archivo co_res1
# []
# no existe el archivo co_res2
# []
# no existe el archivo co_res3
# []
# no existe el archivo co_res4
# []
# no existe el archivo co_res5
# []
# no existe el archivo co_res6
# []
# no existe el archivo co_res7
# []
# no existe el archivo co_res8
# []
# no existe el archivo co_reg1
# []
# no existe el archivo co_reg2
# []
# no existe el archivo co_reg3
# []
# no existe el archivo co_reg4
# []
# no existe el archivo co_reg5
# []
# no existe el archivo co_reg6
# []
# no existe el archivo co_reg7
# []
# no existe el archivo co_reg8
# []
# no existe el archivo hc_cli1
# []
# no existe el archivo hc_cli2
# []
# no existe el archivo hc_cli3
# []
# no existe el archivo hc_cli4
# []
# no existe el archivo hc_cli5
# []
# no existe el archivo hc_cli6
# []
# no existe el archivo hc_cli7
# []
# no existe el archivo hc_cli8
# []
# no existe el archivo hc_diag1
# []
# no existe el archivo hc_diag2
# []
# no existe el archivo hc_diag3
# []
# no existe el archivo hc_diag4
# []
# no existe el archivo hc_diag5
# []
# no existe el archivo hc_diag6
# []
# no existe el archivo hc_diag7
# []
# no existe el archivo hc_diag8
# []
# no existe el archivo hc_lab1
# []
# no existe el archivo hc_lab2
# []
# no existe el archivo hc_lab3
# []
# no existe el archivo hc_lab4
# []
# no existe el archivo hc_lab5
# []
# no existe el archivo hc_lab6
# []
# no existe el archivo hc_lab7
# []
# no existe el archivo hc_lab8
# ['C:/projects/pdf_mining/data\\hc_cem1a.pdf']
# hc_cem1
# ['C:/projects/pdf_mining/data\\hc_cem2a.pdf']
# hc_cem2
# ['C:/projects/pdf_mining/data\\hc_cem3a.pdf']
# hc_cem3
# ['C:/projects/pdf_mining/data\\hc_cem4a.pdf']
# hc_cem4
# ['C:/projects/pdf_mining/data\\hc_cem5a.pdf']
# hc_cem5
# ['C:/projects/pdf_mining/data\\hc_cem6a.pdf']
# hc_cem6
# ['C:/projects/pdf_mining/data\\hc_cem7a.pdf']
# hc_cem7
# ['C:/projects/pdf_mining/data\\hc_cem8a.pdf', 'C:/projects/pdf_mining/data\\hc_cem8b.pdf']
# hc_cem8
# ['C:/projects/pdf_mining/data\\hc_hos1a.pdf']
# hc_hos1
# ['C:/projects/pdf_mining/data\\hc_hos2a.pdf']
# hc_hos2
# ['C:/projects/pdf_mining/data\\hc_hos3a.pdf']
# hc_hos3
# ['C:/projects/pdf_mining/data\\hc_hos4a.pdf']
# hc_hos4
# ['C:/projects/pdf_mining/data\\hc_hos5a.pdf']
# hc_hos5
# ['C:/projects/pdf_mining/data\\hc_hos6a.pdf']
# hc_hos6
# ['C:/projects/pdf_mining/data\\hc_hos7a.pdf']
# hc_hos7
# ['C:/projects/pdf_mining/data\\hc_hos8a.pdf']
# hc_hos8
# ['C:/projects/pdf_mining/data\\hc_ima1a.pdf']
# hc_ima1
# ['C:/projects/pdf_mining/data\\hc_ima2a.pdf']
# hc_ima2
# ['C:/projects/pdf_mining/data\\hc_ima3a.pdf']
# hc_ima3
# ['C:/projects/pdf_mining/data\\hc_ima4a.pdf']
# hc_ima4
# ['C:/projects/pdf_mining/data\\hc_ima5a.pdf']
# hc_ima5
# ['C:/projects/pdf_mining/data\\hc_ima6a.pdf']
# hc_ima6
# ['C:/projects/pdf_mining/data\\hc_ima7a.pdf']
# hc_ima7
# ['C:/projects/pdf_mining/data\\hc_ima8a.pdf']
# hc_ima8
# []
# no existe el archivo hc_rad1
# []
# no existe el archivo hc_rad2
# []
# no existe el archivo hc_rad3
# []
# no existe el archivo hc_rad4
# []
# no existe el archivo hc_rad5
# []
# no existe el archivo hc_rad6
# []
# no existe el archivo hc_rad7
# []
# no existe el archivo hc_rad8
# []
# no existe el archivo hc_res1
# []
# no existe el archivo hc_res2
# []
# no existe el archivo hc_res3
# []
# no existe el archivo hc_res4
# []
# no existe el archivo hc_res5
# []
# no existe el archivo hc_res6
# []
# no existe el archivo hc_res7
# []
# no existe el archivo hc_res8
# []
# no existe el archivo hc_reg1
# []
# no existe el archivo hc_reg2
# []
# no existe el archivo hc_reg3
# []
# no existe el archivo hc_reg4
# []
# no existe el archivo hc_reg5
# []
# no existe el archivo hc_reg6
# []
# no existe el archivo hc_reg7
# []
# no existe el archivo hc_reg8
# ['C:/projects/pdf_mining/data\\la_cli1a.pdf']
# la_cli1
# ['C:/projects/pdf_mining/data\\la_cli2a.pdf']
# la_cli2
# ['C:/projects/pdf_mining/data\\la_cli3a.pdf']
# la_cli3
# ['C:/projects/pdf_mining/data\\la_cli4a.pdf']
# la_cli4
# ['C:/projects/pdf_mining/data\\la_cli5a.pdf']
# la_cli5
# ['C:/projects/pdf_mining/data\\la_cli6a.pdf']
# la_cli6
# ['C:/projects/pdf_mining/data\\la_cli7a.pdf']
# la_cli7
# ['C:/projects/pdf_mining/data\\la_cli8a.pdf']
# la_cli8
# []
# no existe el archivo la_diag1
# []
# no existe el archivo la_diag2
# []
# no existe el archivo la_diag3
# []
# no existe el archivo la_diag4
# []
# no existe el archivo la_diag5
# []
# no existe el archivo la_diag6
# []
# no existe el archivo la_diag7
# []
# no existe el archivo la_diag8
# ['C:/projects/pdf_mining/data\\la_lab1a.pdf']
# la_lab1
# ['C:/projects/pdf_mining/data\\la_lab2a.pdf']
# la_lab2
# ['C:/projects/pdf_mining/data\\la_lab3a.pdf']
# la_lab3
# ['C:/projects/pdf_mining/data\\la_lab4a.pdf']
# la_lab4
# ['C:/projects/pdf_mining/data\\la_lab5a.pdf']
# la_lab5
# ['C:/projects/pdf_mining/data\\la_lab6a.pdf']
# la_lab6
# ['C:/projects/pdf_mining/data\\la_lab7a.pdf']
# la_lab7
# ['C:/projects/pdf_mining/data\\la_lab8a.pdf']
# la_lab8
# []
# no existe el archivo la_cem1
# []
# no existe el archivo la_cem2
# []
# no existe el archivo la_cem3
# []
# no existe el archivo la_cem4
# []
# no existe el archivo la_cem5
# []
# no existe el archivo la_cem6
# []
# no existe el archivo la_cem7
# []
# no existe el archivo la_cem8
# []
# no existe el archivo la_hos1
# []
# no existe el archivo la_hos2
# []
# no existe el archivo la_hos3
# []
# no existe el archivo la_hos4
# []
# no existe el archivo la_hos5
# []
# no existe el archivo la_hos6
# []
# no existe el archivo la_hos7
# []
# no existe el archivo la_hos8
# []
# no existe el archivo la_ima1
# []
# no existe el archivo la_ima2
# []
# no existe el archivo la_ima3
# []
# no existe el archivo la_ima4
# []
# no existe el archivo la_ima5
# []
# no existe el archivo la_ima6
# []
# no existe el archivo la_ima7
# []
# no existe el archivo la_ima8
# ['C:/projects/pdf_mining/data\\la_rad1a.pdf']
# la_rad1
# ['C:/projects/pdf_mining/data\\la_rad2a.pdf']
# la_rad2
# ['C:/projects/pdf_mining/data\\la_rad3a.pdf']
# la_rad3
# ['C:/projects/pdf_mining/data\\la_rad4a.pdf']
# la_rad4
# ['C:/projects/pdf_mining/data\\la_rad5a.pdf']
# la_rad5
# ['C:/projects/pdf_mining/data\\la_rad6a.pdf']
# la_rad6
# ['C:/projects/pdf_mining/data\\la_rad7a.pdf']
# la_rad7
# ['C:/projects/pdf_mining/data\\la_rad8a.pdf']
# la_rad8
# ['C:/projects/pdf_mining/data\\la_res1a.pdf']
# la_res1
# ['C:/projects/pdf_mining/data\\la_res2a.pdf']
# la_res2
# ['C:/projects/pdf_mining/data\\la_res3a.pdf']
# la_res3
# ['C:/projects/pdf_mining/data\\la_res4a.pdf']
# la_res4
# ['C:/projects/pdf_mining/data\\la_res5a.pdf']
# la_res5
# ['C:/projects/pdf_mining/data\\la_res6a.pdf']
# la_res6
# ['C:/projects/pdf_mining/data\\la_res7a.pdf']
# la_res7
# ['C:/projects/pdf_mining/data\\la_res8a.pdf']
# la_res8
# []
# no existe el archivo la_reg1
# []
# no existe el archivo la_reg2
# []
# no existe el archivo la_reg3
# []
# no existe el archivo la_reg4
# []
# no existe el archivo la_reg5
# []
# no existe el archivo la_reg6
# []
# no existe el archivo la_reg7
# []
# no existe el archivo la_reg8
# ['C:/projects/pdf_mining/data\\li_cli1a.pdf']
# li_cli1
# ['C:/projects/pdf_mining/data\\li_cli2a.pdf']
# li_cli2
# ['C:/projects/pdf_mining/data\\li_cli3a.pdf']
# li_cli3
# ['C:/projects/pdf_mining/data\\li_cli4a.pdf']
# li_cli4
# ['C:/projects/pdf_mining/data\\li_cli5a.pdf']
# li_cli5
# ['C:/projects/pdf_mining/data\\li_cli6a.pdf']
# li_cli6
# ['C:/projects/pdf_mining/data\\li_cli7a.pdf']
# li_cli7
# ['C:/projects/pdf_mining/data\\li_cli8a.pdf']
# li_cli8
# []
# no existe el archivo li_diag1
# []
# no existe el archivo li_diag2
# []
# no existe el archivo li_diag3
# []
# no existe el archivo li_diag4
# []
# no existe el archivo li_diag5
# []
# no existe el archivo li_diag6
# []
# no existe el archivo li_diag7
# []
# no existe el archivo li_diag8
# []
# no existe el archivo li_lab1
# []
# no existe el archivo li_lab2
# []
# no existe el archivo li_lab3
# []
# no existe el archivo li_lab4
# []
# no existe el archivo li_lab5
# []
# no existe el archivo li_lab6
# []
# no existe el archivo li_lab7
# []
# no existe el archivo li_lab8
# ['C:/projects/pdf_mining/data\\li_cem1a.pdf']
# li_cem1
# ['C:/projects/pdf_mining/data\\li_cem2a.pdf']
# li_cem2
# ['C:/projects/pdf_mining/data\\li_cem3a.pdf']
# li_cem3
# ['C:/projects/pdf_mining/data\\li_cem4a.pdf']
# li_cem4
# ['C:/projects/pdf_mining/data\\li_cem5a.pdf']
# li_cem5
# ['C:/projects/pdf_mining/data\\li_cem6a.pdf']
# li_cem6
# ['C:/projects/pdf_mining/data\\li_cem7a.pdf']
# li_cem7
# ['C:/projects/pdf_mining/data\\li_cem8a.pdf']
# li_cem8
# []
# no existe el archivo li_hos1
# []
# no existe el archivo li_hos2
# []
# no existe el archivo li_hos3
# []
# no existe el archivo li_hos4
# []
# no existe el archivo li_hos5
# []
# no existe el archivo li_hos6
# []
# no existe el archivo li_hos7
# []
# no existe el archivo li_hos8
# []
# no existe el archivo li_ima1
# []
# no existe el archivo li_ima2
# []
# no existe el archivo li_ima3
# []
# no existe el archivo li_ima4
# []
# no existe el archivo li_ima5
# []
# no existe el archivo li_ima6
# []
# no existe el archivo li_ima7
# []
# no existe el archivo li_ima8
# []
# no existe el archivo li_rad1
# []
# no existe el archivo li_rad2
# []
# no existe el archivo li_rad3
# []
# no existe el archivo li_rad4
# []
# no existe el archivo li_rad5
# []
# no existe el archivo li_rad6
# []
# no existe el archivo li_rad7
# []
# no existe el archivo li_rad8
# []
# no existe el archivo li_res1
# []
# no existe el archivo li_res2
# []
# no existe el archivo li_res3
# []
# no existe el archivo li_res4
# []
# no existe el archivo li_res5
# []
# no existe el archivo li_res6
# []
# no existe el archivo li_res7
# []
# no existe el archivo li_res8
# []
# no existe el archivo li_reg1
# []
# no existe el archivo li_reg2
# []
# no existe el archivo li_reg3
# []
# no existe el archivo li_reg4
# []
# no existe el archivo li_reg5
# []
# no existe el archivo li_reg6
# []
# no existe el archivo li_reg7
# []
# no existe el archivo li_reg8
# ['C:/projects/pdf_mining/data\\po_cli1a.pdf']
# po_cli1
# ['C:/projects/pdf_mining/data\\po_cli2a.pdf']
# po_cli2
# ['C:/projects/pdf_mining/data\\po_cli3a.pdf']
# po_cli3
# ['C:/projects/pdf_mining/data\\po_cli4a.pdf']
# po_cli4
# ['C:/projects/pdf_mining/data\\po_cli5a.pdf']
# po_cli5
# ['C:/projects/pdf_mining/data\\po_cli6a.pdf']
# po_cli6
# ['C:/projects/pdf_mining/data\\po_cli7a.pdf']
# po_cli7
# ['C:/projects/pdf_mining/data\\po_cli8a.pdf']
# po_cli8
# []
# no existe el archivo po_diag1
# []
# no existe el archivo po_diag2
# []
# no existe el archivo po_diag3
# []
# no existe el archivo po_diag4
# []
# no existe el archivo po_diag5
# []
# no existe el archivo po_diag6
# []
# no existe el archivo po_diag7
# []
# no existe el archivo po_diag8
# []
# no existe el archivo po_lab1
# []
# no existe el archivo po_lab2
# []
# no existe el archivo po_lab3
# []
# no existe el archivo po_lab4
# []
# no existe el archivo po_lab5
# []
# no existe el archivo po_lab6
# []
# no existe el archivo po_lab7
# []
# no existe el archivo po_lab8
# []
# no existe el archivo po_cem1
# []
# no existe el archivo po_cem2
# []
# no existe el archivo po_cem3
# []
# no existe el archivo po_cem4
# []
# no existe el archivo po_cem5
# []
# no existe el archivo po_cem6
# []
# no existe el archivo po_cem7
# []
# no existe el archivo po_cem8
# []
# no existe el archivo po_hos1
# []
# no existe el archivo po_hos2
# []
# no existe el archivo po_hos3
# []
# no existe el archivo po_hos4
# []
# no existe el archivo po_hos5
# []
# no existe el archivo po_hos6
# []
# no existe el archivo po_hos7
# []
# no existe el archivo po_hos8
# []
# no existe el archivo po_ima1
# []
# no existe el archivo po_ima2
# []
# no existe el archivo po_ima3
# []
# no existe el archivo po_ima4
# []
# no existe el archivo po_ima5
# []
# no existe el archivo po_ima6
# []
# no existe el archivo po_ima7
# []
# no existe el archivo po_ima8
# []
# no existe el archivo po_rad1
# []
# no existe el archivo po_rad2
# []
# no existe el archivo po_rad3
# []
# no existe el archivo po_rad4
# []
# no existe el archivo po_rad5
# []
# no existe el archivo po_rad6
# []
# no existe el archivo po_rad7
# []
# no existe el archivo po_rad8
# []
# no existe el archivo po_res1
# []
# no existe el archivo po_res2
# []
# no existe el archivo po_res3
# []
# no existe el archivo po_res4
# []
# no existe el archivo po_res5
# []
# no existe el archivo po_res6
# []
# no existe el archivo po_res7
# []
# no existe el archivo po_res8
# ['C:/projects/pdf_mining/data\\po_reg1a.pdf']
# po_reg1
# ['C:/projects/pdf_mining/data\\po_reg2a.pdf']
# po_reg2
# ['C:/projects/pdf_mining/data\\po_reg3a.pdf']
# po_reg3
# ['C:/projects/pdf_mining/data\\po_reg4a.pdf']
# po_reg4
# ['C:/projects/pdf_mining/data\\po_reg5a.pdf']
# po_reg5
# ['C:/projects/pdf_mining/data\\po_reg6a.pdf']
# po_reg6
# ['C:/projects/pdf_mining/data\\po_reg7a.pdf']
# po_reg7
# ['C:/projects/pdf_mining/data\\po_reg8a.pdf']
# po_reg8
# ['C:/projects/pdf_mining/data\\pu_cli1a.pdf']
# pu_cli1
# ['C:/projects/pdf_mining/data\\pu_cli2a.pdf']
# pu_cli2
# ['C:/projects/pdf_mining/data\\pu_cli3a.pdf']
# pu_cli3
# ['C:/projects/pdf_mining/data\\pu_cli4a.pdf']
# pu_cli4
# ['C:/projects/pdf_mining/data\\pu_cli5a.pdf']
# pu_cli5
# ['C:/projects/pdf_mining/data\\pu_cli6a.pdf']
# pu_cli6
# ['C:/projects/pdf_mining/data\\pu_cli7a.pdf']
# pu_cli7
# ['C:/projects/pdf_mining/data\\pu_cli8a.pdf', 'C:/projects/pdf_mining/data\\pu_cli8b.pdf']
# pu_cli8
# []
# no existe el archivo pu_diag1
# []
# no existe el archivo pu_diag2
# []
# no existe el archivo pu_diag3
# []
# no existe el archivo pu_diag4
# []
# no existe el archivo pu_diag5
# []
# no existe el archivo pu_diag6
# []
# no existe el archivo pu_diag7
# []
# no existe el archivo pu_diag8
# []
# no existe el archivo pu_lab1
# []
# no existe el archivo pu_lab2
# []
# no existe el archivo pu_lab3
# []
# no existe el archivo pu_lab4
# []
# no existe el archivo pu_lab5
# []
# no existe el archivo pu_lab6
# []
# no existe el archivo pu_lab7
# []
# no existe el archivo pu_lab8
# ['C:/projects/pdf_mining/data\\pu_cem1a.pdf']
# pu_cem1
# ['C:/projects/pdf_mining/data\\pu_cem2a.pdf']
# pu_cem2
# ['C:/projects/pdf_mining/data\\pu_cem3a.pdf']
# pu_cem3
# ['C:/projects/pdf_mining/data\\pu_cem4a.pdf']
# pu_cem4
# ['C:/projects/pdf_mining/data\\pu_cem5a.pdf']
# pu_cem5
# ['C:/projects/pdf_mining/data\\pu_cem6a.pdf']
# pu_cem6
# ['C:/projects/pdf_mining/data\\pu_cem7a.pdf']
# pu_cem7
# ['C:/projects/pdf_mining/data\\pu_cem8a.pdf', 'C:/projects/pdf_mining/data\\pu_cem8b.pdf']
# pu_cem8
# []
# no existe el archivo pu_hos1
# []
# no existe el archivo pu_hos2
# []
# no existe el archivo pu_hos3
# []
# no existe el archivo pu_hos4
# []
# no existe el archivo pu_hos5
# []
# no existe el archivo pu_hos6
# []
# no existe el archivo pu_hos7
# []
# no existe el archivo pu_hos8
# []
# no existe el archivo pu_ima1
# []
# no existe el archivo pu_ima2
# []
# no existe el archivo pu_ima3
# []
# no existe el archivo pu_ima4
# []
# no existe el archivo pu_ima5
# []
# no existe el archivo pu_ima6
# []
# no existe el archivo pu_ima7
# []
# no existe el archivo pu_ima8
# []
# no existe el archivo pu_rad1
# []
# no existe el archivo pu_rad2
# []
# no existe el archivo pu_rad3
# []
# no existe el archivo pu_rad4
# []
# no existe el archivo pu_rad5
# []
# no existe el archivo pu_rad6
# []
# no existe el archivo pu_rad7
# []
# no existe el archivo pu_rad8
# []
# no existe el archivo pu_res1
# []
# no existe el archivo pu_res2
# []
# no existe el archivo pu_res3
# []
# no existe el archivo pu_res4
# []
# no existe el archivo pu_res5
# []
# no existe el archivo pu_res6
# []
# no existe el archivo pu_res7
# []
# no existe el archivo pu_res8
# []
# no existe el archivo pu_reg1
# []
# no existe el archivo pu_reg2
# []
# no existe el archivo pu_reg3
# []
# no existe el archivo pu_reg4
# []
# no existe el archivo pu_reg5
# []
# no existe el archivo pu_reg6
# []
# no existe el archivo pu_reg7
# []
# no existe el archivo pu_reg8

# %%
df.to_csv('raw_data2.csv', index=False, sep=';')

# %%
df.head()
# Out:
# 0         RUT Apellido Paterno Apellido Materno             Nombres  \
# 0  14102553-8         AGUILERA           CORTES        ANA ANYELINA
# 1  16248551-2          AHUMADA        BALBONTIN          MARIA INES
# 2  11617329-8          ALARCON           COLLAO  MARCELA DEL CARMEN
# 3  15458350-5          ALARCON             RIOS    FERNANDA CECILIA
# 4  16013018-0            ALDAY           CORTÉS      JOSELYN NATALY
#
# 0 Remuneración Movimiento Fecha Inicio Fecha Termino grupo mes sociedad
# 0      1478682          0          NaN           NaN    at   1      cli
# 1       559112          2   30/01/2020    31/01/2020    at   1      cli
# 2       442534          0          NaN           NaN    at   1      cli
# 3       977201          0          NaN           NaN    at   1      cli
# 4      1263135          0          NaN           NaN    at   1      cli

# %%
df['Remuneración'].astype('int').sum()
# Out:
# 10668601763

# %%
df.shape
# Out:
# (15029, 11)

# %%
df['grupo'].unique()
# Out:
# array(['at', 'co', 'hc', 'la', 'li', 'po', 'pu'], dtype=object)

# %%
df[df['grupo']=='la']
# Out:
# 0          RUT Apellido Paterno Apellido Materno            Nombres  \
# 0   18535994-8          ACEVEDO            RIVAS     SUSAN SCARLETT
# 1   10326456-1           ACOSTA       VALENZUELA  MONICA DEL CARMEN
# 2   16395578-4            ACUÑA            ACUÑA       ELISA ANDREA
# 3   10219126-9            ACUÑA             MELO      JUAN BERNARDO
# 4   11243904-8             AEDO           MEJIAS  ANTONELLA MARISOL
# ..         ...              ...              ...                ...
# 3   15695576-0            REYES          LLANTEN     BORIS LEONARDO
# 0   10057512-4         CARRASCO          CORDOVA    ALEJANDRO MARIO
# 1   17592626-7       CHEUQUELAF            OPAZO      KAREN CECILIA
# 2   12922847-4           GATICA           ROLDAN     ARTURO ESTEBAN
# 3   15695576-0            REYES          LLANTEN     BORIS LEONARDO
#
# 0  Remuneración Movimiento Fecha Inicio Fecha Termino grupo mes sociedad
# 0        420799          0          NaN           NaN    la   1      cli
# 1        419566          0          NaN           NaN    la   1      cli
# 2        519135          0          NaN           NaN    la   1      cli
# 3        514703          0          NaN           NaN    la   1      cli
# 4        528308          0          NaN           NaN    la   1      cli
# ..          ...        ...          ...           ...   ...  ..      ...
# 3       1353301          2   12/07/2020    14/07/2020    la   7      res
# 0       2300092          0          NaN           NaN    la   8      res
# 1        413753          0          NaN           NaN    la   8      res
# 2        560898          0          NaN           NaN    la   8      res
# 3        959090          2   13/08/2020    24/08/2020    la   8      res
#
# [2183 rows x 11 columns]

# %%
df.to_csv('raw_data3.csv', index=False, sep=';')
